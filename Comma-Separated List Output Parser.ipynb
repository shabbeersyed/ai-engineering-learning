# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
chat = ChatOpenAI(model_name = 'gpt-4',
                 seed = 365,
                 temperature = 0,
                 max_tokens = 100)

# %%
message_h = HumanMessage(content = f'''I've recently adopted a dog. Coul;d you suggest some dog names?
{CommaSeparatedListOutputParser().get_format_instructions()}
''')

# %%
print(message_h)
# Out:
# content="I've recently adopted a dog. Coul;d you suggest some dog names?\nYour response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`\n" additional_kwargs={} response_metadata={}

# %% [raw]
# response = chat.invoke([message_h])

# %%
print(response.content)
# Out:
# Sure, here are some suggestions:
#
# Male Dog Names:
# 1. Max
# 2. Charlie
# 3. Cooper
# 4. Buddy
# 5. Jack
# 6. Rocky
# 7. Duke
# 8. Bear
# 9. Tucker
# 10. Oliver
#
# Female Dog Names:
# 1. Bella
# 2. Lucy
# 3. Daisy
# 4. Luna
# 5. Lola
# 6. Sadie
# 7. Molly
# 8. Bailey
# 9. Stella
# 10. Maggie
#
# Unisex Dog Names

# %%
list_output_parser = CommaSeparatedListOutputParser()

# %%
response_parsed = list_output_parser.invoke(response)

# %%
response_parsed
# Out:
# ['Sure',
#  'here are some suggestions:',
#  'Male Dog Names:',
#  '1. Max',
#  '2. Charlie',
#  '3. Cooper',
#  '4. Buddy',
#  '5. Jack',
#  '6. Rocky',
#  '7. Duke',
#  '8. Bear',
#  '9. Tucker',
#  '10. Oliver',
#  'Female Dog Names:',
#  '1. Bella',
#  '2. Lucy',
#  '3. Daisy',
#  '4. Luna',
#  '5. Lola',
#  '6. Sadie',
#  '7. Molly',
#  '8. Bailey',
#  '9. Stella',
#  '10. Maggie',
#  'Unisex Dog Names']

# %%
print(list_output_parser.get_format_instructions())
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`
