# %%
# %load_ext dotenv
# %dotenv

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import CommaSeparatedListOutputParser

# %%
parser = CommaSeparatedListOutputParser()
list_instructions = parser.get_format_instructions()
print(list_instructions)
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
chat_template = ChatPromptTemplate.from_messages([('human', "I've recently adopted a {pet}. Could you suggest three {pet} names? \n" + list_instructions)])

# %%
print(chat_template.messages[0].prompt.template)
# Out:
# I've recently adopted a pet

# %%
chat = ChatOpenAI(model_name = 'gpt-4', seed = 365, temperature = 0, max_tokens = 100)

# %%
chat = ChatOpenAI(
    model_name='gpt-4',
    seed = 365,
    temperature=0,
    max_tokens=100
)

# %%
list_output_parser = CommaSeparatedListOutputParser()

# %%
chat_template_result = chat_template.invoke({'pet': 'dog'})

# %%
chat_result = chat.invoke(chat_template_result)

# %%
list_output_parser.invoke(chat_result)
# Out:
# ["That's great! What kind of pet did you adopt? A dog",
#  'cat',
#  'bird',
#  'or maybe a reptile?']

# %%
chain = ch
