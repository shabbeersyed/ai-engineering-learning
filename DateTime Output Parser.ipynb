# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
pip install -U langchain-classic
# Out:
# Collecting langchain-classic
#   Downloading langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Collecting async-timeout<5.0.0,>=4.0.0 (from langchain-classic)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.19 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-classic) (1.2.26)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-classic) (0.7.25)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-classic) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-classic) (2.33.1)
# Collecting sqlalchemy<3.0.0,>=1.4.0 (from langchain-classic)
#   Downloading sqlalchemy-2.0.49-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (26.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in .\anaconda3\envs\langchain_env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.19->langchain-classic) (3.1.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in .\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: anyio in .\anaconda3\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.13.0)
# Requirement already satisfied: certifi in .\anaconda3\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\anaconda3\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: idna in .\anaconda3\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11)
# Requirement already satisfied: h11>=0.16 in .\anaconda3\envs\langchain_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\anaconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\anaconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\anaconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\anaconda3\envs\langchain_env\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in .\anaconda3\envs\langchain_env\lib\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.6.3)
# Collecting greenlet>=1 (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic)
#   Downloading greenlet-3.3.2-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\anaconda3\envs\langchain_env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.3.1)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 12.6 MB/s  0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading sqlalchemy-2.0.49-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 20.0 MB/s  0:00:00
# Downloading greenlet-3.3.2-cp310-cp310-win_amd64.whl (230 kB)
# Installing collected packages: greenlet, async-timeout, sqlalchemy, langchain-text-splitters, langchain-classic
#
#    ---------------------------------------- 0/5 [greenlet]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ------------------------ --------------- 3/5 [langchain-text-splitters]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    -------------------------------- ------- 4/5 [langchain-classic]
#    ---------------------------------------- 5/5 [langchain-classic]
#
# Successfully installed async-timeout-4.0.3 greenlet-3.3.2 langchain-classic-1.0.3 langchain-text-splitters-1.1.1 sqlalchemy-2.0.49
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_classic.output_parsers import DatetimeOutputParser

# %%
chat = ChatOpenAI(model_name = 'gpt-4',
                 seed = 365,
                 temperature = 0,
                 max_tokens = 100)

# %%
message_h = HumanMessage(content = f'''When was the Danish poet Piet hein born?
{DatetimeOutputParser().get_format_instructions()}''')

# %%
print(message_h.content)
# Out:
# When was the Danish poet Piet hein born?
# Write a datetime string that matches the following pattern: '%Y-%m-%dT%H:%M:%S.%fZ'.
#
# Examples: 2023-07-04T14:30:00.000000Z, 1999-12-31T23:59:59.999999Z, 2025-01-01T00:00:00.000000Z
#
# Return ONLY this string, no other words!

# %%
response = chat.invoke([message_h])

# %%
print(response.content)
# Out:
# 1905-12-16T00:00:00.000000Z

# %%
date_output_parser = DatetimeOutputParser()

# %%
response_parsed = date_output_parser.invoke(response)

# %%
print(response_parsed)
# Out:
# 1905-12-16 00:00:00

# %%
print(date_output_parser.get_format_instructions())
# Out:
# Write a datetime string that matches the following pattern: '%Y-%m-%dT%H:%M:%S.%fZ'.
#
# Examples: 2023-07-04T14:30:00.000000Z, 1999-12-31T23:59:59.999999Z, 2025-01-01T00:00:00.000000Z
#
# Return ONLY this string, no other words!
